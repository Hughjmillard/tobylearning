# %%
print("Yo")
# Out:
# Yo

# %%
from Functions import do_something

# %%
x  = do_something(2)

print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 x  = do_something(2)
#       3 print(x)
#
# TypeError: do_something() takes 0 positional arguments but 1 was given

# %%
from Classes import Task
downtime_1 = 3
downtime_2 = 5
downtime_3 = 7

task_1 = Task(downtime_1)

task_2 = Task(downtime_2)

task_3 = Task(downtime_3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 6
#       3 downtime = 5
#       4 downtime = 7
# ----> 6 task_1 = Task(downtime_1)
#       8 task_2 = Task(downtime_2)
#      10 task_3 = Task(downtime_3)
#
# NameError: name 'downtime_1' is not defined

# %%
print(task_1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 print(task_1)
#
# TypeError: __str__ returned non-string (type tuple)
