# %%
print("Yo")
# Out:
# Yo

# %%
from Functions import do_something

# %%
x  = do_something(2)

print(x)
# Out:
# 4

# %%
from Classes import Task Person
downtime_1 = 3
downtime_2 = 5
downtime_3 = 7

task_1 = Task(downtime_1)

task_2 = Task(downtime_2)

task_3 = Task(downtime_3)
# Out:
#   Cell In[4], line 1
#     from Classes import Task Person
#                              ^
# SyntaxError: invalid syntax

# %%
from Classes import Person

p1 = Person("Lisa", "UK", "Danbury", age = 52)

p1.aging(5)

p1.age

p1.greet()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 10
#       6 p1.aging(5)
#       8 p1.age
# ---> 10 p1.greet()
#
# AttributeError: 'Person' object has no attribute 'greet'

# %% [markdown]
# # Car

# %%
from Classes import Car

# %%
car1 = Car("GT Silver","Porsche","718 Spyder", 4.0, 1400,"RWD", 2)

car1.display_info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 3
#       1 car1 = Car("GT Silver","Porsche","718 Spyder", 4.0, 1400,"RWD", 2)
# ----> 3 car1.display_info()
#
# AttributeError: 'Car' object has no attribute 'display_info'
